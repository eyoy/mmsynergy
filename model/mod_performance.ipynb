# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
# Out:
# /home/research/anaconda3/envs/multibench/lib/python3.8/site-packages/pandas/core/computation/expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %% [markdown]
# ### MulT-Contextual

# %%
test_perf_path = '/mnt/g/mmsynergy/model/tune/mult_contextual/comment/checkpoints/test/'
paths = [test_perf_path+i for i in os.listdir(test_perf_path)]
names = []
all_data = []
for p in paths:
    name = p.split('/')[-1].split('_seq')[0]
    data = torch.load(p)
    data = pd.DataFrame([data])
    data['name'] = name
    all_data.append(data)

all_data = pd.concat(all_data)
all_data = all_data.loc[:, ~all_data.columns.str.contains('random')]

# %%
all_data
# Out:
#        LOSS       MAE       MSE      RMSE          MAPE        R2  \
# 0  1.220535  1.220535  2.555638  1.598636  9.630608e+14  0.515565
# 0  1.255723  1.255723  2.738216  1.654756  8.345439e+14  0.480957
# 0  1.265166  1.265165  2.804626  1.674702  8.859456e+14  0.468368
# 0  1.203831  1.203831  2.540430  1.593873  9.097396e+14  0.518448
#
#                     name
# 0   perf_lr0.001_bs64.pt
# 0  perf_lr0.0001_bs64.pt
# 0   perf_lr0.005_bs64.pt
# 0  perf_lr0.0005_bs64.pt

# %%
test_perf_path = '/mnt/g/mmsynergy/model/tune/mult_contextual/digg/checkpoints/test/'
paths = [test_perf_path+i for i in os.listdir(test_perf_path)]
names = []
all_data = []
for p in paths:
    name = p.split('/')[-1].split('_seq')[0]
    data = torch.load(p)
    data = pd.DataFrame([data])
    data['name'] = name
    all_data.append(data)

all_data = pd.concat(all_data)
all_data = all_data.loc[:, ~all_data.columns.str.contains('random')]

# %%
all_data.sort_values('LOSS')
# Out:
#        LOSS       MAE       MSE      RMSE          MAPE        R2  \
# 0  1.326187  1.326187  3.336668  1.826655  7.197593e+12  0.638535
# 0  1.326918  1.326918  3.406007  1.845537  7.281229e+12  0.631024
# 0  1.341752  1.341752  3.453979  1.858488  8.046374e+12  0.625827
# 0  1.352559  1.352559  3.453409  1.858335  7.818114e+12  0.625889
# 0  1.353393  1.353393  3.498710  1.870484  7.931377e+12  0.620981
# 0  1.380695  1.380695  3.603282  1.898231  7.898638e+12  0.609653
# 0  1.381197  1.381197  3.564824  1.888074  9.227100e+12  0.613819
# 0  1.413326  1.413325  3.743544  1.934824  7.708832e+12  0.594458
# 0  1.449442  1.449442  3.843085  1.960379  8.550363e+12  0.583675
# 0  1.458103  1.458103  3.901266  1.975162  8.870559e+12  0.577372
# 0  1.459329  1.459329  3.838341  1.959169  8.491645e+12  0.584189
# 0  1.518797  1.518797  4.187272  2.046283  8.854869e+12  0.546389
#
#                      name
# 0   perf_lr0.0005_bs64.pt
# 0   perf_lr0.0005_bs16.pt
# ...

# %%
test_perf_path = '/mnt/g/mmsynergy/model/tune/mult_contextual/play/checkpoints/test/'
paths = [test_perf_path+i for i in os.listdir(test_perf_path)]
names = []
all_data = []
for p in paths:
    name = p.split('/')[-1].split('_seq')[0]
    data = torch.load(p)
    data = pd.DataFrame([data])
    data['name'] = name
    all_data.append(data)

all_data = pd.concat(all_data)
all_data = all_data.loc[:, ~all_data.columns.str.contains('random')]

# %%
all_data.sort_values('LOSS')
# Out:
#        LOSS       MAE       MSE      RMSE      MAPE        R2  \
# 0  1.400213  1.400213  3.615847  1.901538  0.167055  0.595785
# 0  1.411121  1.411122  3.620738  1.902824  0.168844  0.595239
# 0  1.417962  1.417962  3.662644  1.913804  0.171244  0.590554
# 0  1.420821  1.420822  3.724871  1.929993  0.169145  0.583598
# 0  1.426833  1.426833  3.724398  1.929870  0.170535  0.583650
# 0  1.432606  1.432607  3.753055  1.937280  0.171120  0.580447
# 0  1.437038  1.437038  3.734192  1.932406  0.173934  0.582556
# 0  1.466799  1.466799  3.912915  1.978109  0.172375  0.562576
# 0  1.490805  1.490805  3.948363  1.987049  0.178436  0.558614
# 0  1.530746  1.530746  4.036076  2.008999  0.189922  0.548808
# 0  1.607374  1.607374  4.407113  2.099312  0.197370  0.507330
# 0  1.622351  1.622351  4.558564  2.135079  0.192742  0.490399
#
#                      name
# 0   perf_lr0.0005_bs64.pt
# 0   perf_lr0.001_bs128.pt
# 0    perf_lr0.001_bs16.pt
# 0   perf_lr0.0005_bs16.pt
# ...

# %% [markdown]
# ### MulT-NoCMT-contextual

# %%
test_perf_path = '/mnt/g/mmsynergy/model/tune/mult_nocmt_contextual/comment/checkpoints/test/'
paths = [test_perf_path+i for i in os.listdir(test_perf_path)]
names = []
all_data = []
for p in paths:
    name = p.split('/')[-1].split('_seq')[0]
    data = torch.load(p)
    data = pd.DataFrame([data])
    data['name'] = name
    all_data.append(data)

all_data = pd.concat(all_data)
all_data = all_data.loc[:, ~all_data.columns.str.contains('random')]

# %%
all_data.sort_values('MAE')
# Out:
#         MAE       MSE      RMSE          MAPE        R2                   name
# 0  1.205868  2.561424  1.600445  8.651270e+14  0.514469  perf_lr0.0005_bs16.pt
# 0  1.211153  2.567129  1.602226  8.944672e+14  0.513387   perf_lr0.001_bs64.pt
# 0  1.212910  2.587143  1.608460  8.531917e+14  0.509593  perf_lr0.0005_bs64.pt
# 0  1.227683  2.663793  1.632113  8.401718e+14  0.495064   perf_lr0.001_bs16.pt
# 0  1.246053  2.730011  1.652274  8.467502e+14  0.482512  perf_lr0.0001_bs64.pt
# 0  1.261847  2.767229  1.663499  8.535802e+14  0.475457   perf_lr0.005_bs64.pt
# 0  1.288179  2.868517  1.693670  9.978283e+14  0.456257   perf_lr0.005_bs16.pt

# %%
test_perf_path = '/mnt/g/mmsynergy/model/tune/mult_nocmt_contextual/digg/checkpoints/test/'
paths = [test_perf_path+i for i in os.listdir(test_perf_path)]
names = []
all_data = []
for p in paths:
    name = p.split('/')[-1].split('_seq')[0]
    data = torch.load(p)
    data = pd.DataFrame([data])
    data['name'] = name
    all_data.append(data)

all_data = pd.concat(all_data)
all_data = all_data.loc[:, ~all_data.columns.str.contains('random')]

# %%
all_data.sort_values('MAE')
# Out:
#         MAE       MSE      RMSE          MAPE        R2                   name
# 0  1.330798  3.456299  1.859112  7.460018e+12  0.625576  perf_lr0.0005_bs64.pt
# 0  1.333612  3.488493  1.867751  8.183802e+12  0.622088   perf_lr0.001_bs64.pt
# 0  1.350217  3.520570  1.876318  8.035026e+12  0.618613   perf_lr0.001_bs16.pt
# 0  1.354018  3.509599  1.873392  7.966268e+12  0.619802  perf_lr0.0005_bs16.pt
# 0  1.390580  3.651730  1.910950  8.415358e+12  0.604405  perf_lr0.0001_bs64.pt
# 0  1.477250  4.015836  2.003955  8.285278e+12  0.564961   perf_lr0.005_bs64.pt
# 0  1.487431  4.157170  2.038914  8.457459e+12  0.549650   perf_lr0.005_bs16.pt

# %%
test_perf_path = '/mnt/g/mmsynergy/model/tune/mult_nocmt_contextual/play/checkpoints/test/'
paths = [test_perf_path+i for i in os.listdir(test_perf_path)]
names = []
all_data = []
for p in paths:
    name = p.split('/')[-1].split('_seq')[0]
    data = torch.load(p)
    data = pd.DataFrame([data])
    data['name'] = name
    all_data.append(data)

all_data = pd.concat(all_data)
all_data = all_data.loc[:, ~all_data.columns.str.contains('random')]

# %%
all_data.sort_values('MAE')
# Out:
#         MAE       MSE      RMSE      MAPE        R2                   name
# 0  1.415354  3.643255  1.908731  0.171407  0.592721  perf_lr0.0005_bs64.pt
# 0  1.415778  3.751378  1.936847  0.166717  0.580634   perf_lr0.001_bs16.pt
# 0  1.425848  3.791887  1.947277  0.169932  0.576106  perf_lr0.0005_bs16.pt
# 0  1.439669  3.759506  1.938945  0.173605  0.579726   perf_lr0.001_bs64.pt
# 0  1.471427  3.946959  1.986695  0.174383  0.558770  perf_lr0.0001_bs64.pt
# 0  1.539346  4.181953  2.044982  0.185877  0.532500   perf_lr0.005_bs64.pt

# %% [markdown]
# ### Uni-V-Contextual

# %%
test_perf_path = '/mnt/g/mmsynergy/model/tune/uni_v_context/comment/checkpoints/test/'
paths = [test_perf_path+i for i in os.listdir(test_perf_path)]
names = []
all_data = []
for p in paths:
    name = p.split('/')[-1].split('_seq')[0]
    data = torch.load(p)
    data = pd.DataFrame([data])
    data['name'] = name
    all_data.append(data)

all_data = pd.concat(all_data)
#all_data = all_data.loc[:, ~all_data.columns.str.contains('random')]

# %%
all_data.sort_values('MAE').reset_index(drop=True)
# Out:
#         LOSS       MAE       MSE  RANDOM MAE  RANDOM MSE   \
# 0   1.371505  1.371505  3.355054    1.900691     5.275506
# 1   1.382038  1.382038  3.385915    1.900691     5.275506
# 2   1.385626  1.385625  3.385010    1.900691     5.275506
# 3   1.388777  1.388777  3.397158    1.900691     5.275506
# 4   1.390038  1.390037  3.467866    1.900691     5.275506
# 5   1.407213  1.407213  3.495651    1.900691     5.275506
# 6   1.731932  1.731932  4.809854    1.900691     5.275506
# 7   1.877121  1.877121  5.415484    1.900691     5.275506
# 8   1.877211  1.877210  5.410410    1.900691     5.275506
# 9   1.877492  1.877492  5.396066    1.900691     5.275506
# 10  1.877840  1.877840  5.379125    1.900691     5.275506
# 11  1.878180  1.878179  5.371040    1.900691     5.275506
# 12  1.878224  1.878223  5.370303    1.900691     5.275506
# 13  1.878245  1.878245  5.369945    1.900691     5.275506
# 14  1.878432  1.878433  5.366807    1.900691     5.275506
# ...

# %%
test_perf_path = '/mnt/g/mmsynergy/model/tune/uni_v_context/digg/checkpoints/test/'
paths = [test_perf_path+i for i in os.listdir(test_perf_path)]
names = []
all_data = []
for p in paths:
    name = p.split('/')[-1].split('_seq')[0]
    data = torch.load(p)
    data = pd.DataFrame([data])
    data['name'] = name
    all_data.append(data)

all_data = pd.concat(all_data)
all_data = all_data.loc[:, ~all_data.columns.str.contains('random')]

# %%
all_data.sort_values('MAE').reset_index(drop=True)
# Out:
#         LOSS       MAE       MSE  RANDOM MAE  RANDOM MSE   \
# 0   1.615216  1.615217  5.090962    2.592967     9.230971
# 1   1.625754  1.625754  5.208046    2.592967     9.230971
# 2   1.633557  1.633557  5.156568    2.592967     9.230971
# 3   1.635830  1.635829  5.133198    2.592967     9.230971
# 4   1.644134  1.644134  5.296031    2.592967     9.230971
# 5   1.656992  1.656991  5.349158    2.592967     9.230971
# 6   2.275420  2.275420  9.391035    2.592967     9.230971
# 7   2.535565  2.535564  9.611636    2.592967     9.230971
# 8   2.538378  2.538378  9.520449    2.592967     9.230971
# 9   2.539533  2.539532  9.494921    2.592967     9.230971
# 10  2.540150  2.540149  9.483095    2.592967     9.230971
# 11  2.542010  2.542011  9.451969    2.592967     9.230971
# 12  2.543279  2.543278  9.433458    2.592967     9.230971
# 13  2.546149  2.546149  9.398551    2.592967     9.230971
# 14  2.546906  2.546906  9.390506    2.592967     9.230971
# ...

# %%
test_perf_path = '/mnt/g/mmsynergy/model/tune/uni_v_context/play/checkpoints/test/'
paths = [test_perf_path+i for i in os.listdir(test_perf_path)]
names = []
all_data = []
for p in paths:
    name = p.split('/')[-1].split('_seq')[0]
    data = torch.load(p)
    data = pd.DataFrame([data])
    data['name'] = name
    all_data.append(data)

all_data = pd.concat(all_data)
all_data = all_data.loc[:, ~all_data.columns.str.contains('random')]

# %%
all_data.sort_values('MAE').reset_index(drop=True)
# Out:
#        LOSS       MAE       MSE  RANDOM MAE  RANDOM MSE   \
# 0  1.667579  1.667579  5.230260    2.553878     8.945364
# 1  1.715487  1.715487  5.337278    2.553878     8.945364
# 2  2.520260  2.520258  9.100875    2.553878     8.945364
# 3  2.523477  2.523478  9.055709    2.553878     8.945364
# 4  2.526861  2.526862  9.022959    2.553878     8.945364
# 5  2.531033  2.531033  8.994813    2.553878     8.945364
# 6  2.533530  2.533530  8.982605    2.553878     8.945364
# 7  2.545167  2.545166  8.950975    2.553878     8.945364
#
#                                      name
# 0  perf_lr0.0005_bs128_hid40_hidhid512.pt
# 1   perf_lr0.0005_bs64_hid40_hidhid512.pt
# 2   perf_lr0.0005_bs16_hid40_hidhid512.pt
# 3    perf_lr0.005_bs16_hid40_hidhid512.pt
# 4    perf_lr0.005_bs32_hid40_hidhid512.pt
# 5   perf_lr0.0005_bs32_hid40_hidhid512.pt
# 6   perf_lr0.005_bs128_hid40_hidhid512.pt
# 7    perf_lr0.005_bs64_hid40_hidhid512.pt

# %% [markdown]
# ### Uni-A-Contextual

# %%
test_perf_path = '/mnt/g/mmsynergy/model/tune/uni_a_context/comment/checkpoints/test/'
paths = [test_perf_path+i for i in os.listdir(test_perf_path)]
names = []
all_data = []
for p in paths:
    name = p.split('/')[-1].split('_seq')[0]
    data = torch.load(p)
    data = pd.DataFrame([data])
    data['name'] = name
    all_data.append(data)

all_data = pd.concat(all_data)
all_data = all_data.loc[:, ~all_data.columns.str.contains('random')]

# %%
all_data.sort_values(by = 'MAE')
# Out:
#        LOSS       MAE       MSE  RANDOM MAE  RANDOM MSE   \
# 0  1.221321  1.221321  2.694718    1.900691     5.275506
# 0  1.225715  1.225716  2.731358    1.900691     5.275506
# 0  1.229028  1.229028  2.660940    1.900691     5.275506
# 0  1.234237  1.234237  2.731441    1.900691     5.275506
# 0  1.235934  1.235933  2.708412    1.900691     5.275506
# 0  1.238179  1.238179  2.710061    1.900691     5.275506
# 0  1.246076  1.246075  2.796354    1.900691     5.275506
# 0  1.247404  1.247404  2.813285    1.900691     5.275506
# 0  1.393438  1.393438  3.453405    1.900691     5.275506
# 0  1.700416  1.700416  4.515954    1.900691     5.275506
# 0  1.716879  1.716879  4.768346    1.900691     5.275506
# 0  1.877077  1.877077  5.417671    1.900691     5.275506
# 0  1.877241  1.877240  5.409091    1.900691     5.275506
# 0  1.877812  1.877812  5.380456    1.900691     5.275506
# 0  1.877842  1.877841  5.379092    1.900691     5.275506
# ...

# %%
test_perf_path = '/mnt/g/mmsynergy/model/tune/uni_a_context/digg/checkpoints/test/'
paths = [test_perf_path+i for i in os.listdir(test_perf_path)]
names = []
all_data = []
for p in paths:
    name = p.split('/')[-1].split('_seq')[0]
    data = torch.load(p)
    data = pd.DataFrame([data])
    data['name'] = name
    all_data.append(data)

all_data = pd.concat(all_data)
all_data = all_data.loc[:, ~all_data.columns.str.contains('random')]

# %%
all_data.sort_values(by = 'MAE')
# Out:
#        LOSS       MAE       MSE  RANDOM MAE  RANDOM MSE   \
# 0  1.375249  1.375248  3.757403    2.592967     9.230971
# 0  1.383017  1.383017  3.757543    2.592967     9.230971
# 0  1.405518  1.405519  3.878958    2.592967     9.230971
# 0  1.416743  1.416743  3.917833    2.592967     9.230971
# 0  1.433390  1.433389  3.987735    2.592967     9.230971
# 0  2.369983  2.369983  9.157089    2.592967     9.230971
# 0  2.537326  2.537325  9.547851    2.592967     9.230971
# 0  2.540762  2.540762  9.472054    2.592967     9.230971
# 0  2.541296  2.541294  9.463207    2.592967     9.230971
# 0  2.541422  2.541420  9.461185    2.592967     9.230971
# 0  2.541824  2.541824  9.454830    2.592967     9.230971
# 0  2.541843  2.541844  9.454448    2.592967     9.230971
# 0  2.548085  2.548085  9.378704    2.592967     9.230971
# 0  2.548189  2.548190  9.377692    2.592967     9.230971
# 0  2.549422  2.549422  9.366342    2.592967     9.230971
# ...

# %%
test_perf_path = '/mnt/g/mmsynergy/model/tune/uni_a_context/play/checkpoints/test/'
paths = [test_perf_path+i for i in os.listdir(test_perf_path)]
names = []
all_data = []
for p in paths:
    name = p.split('/')[-1].split('_seq')[0]
    data = torch.load(p)
    data = pd.DataFrame([data])
    data['name'] = name
    all_data.append(data)

all_data = pd.concat(all_data)
all_data = all_data.loc[:, ~all_data.columns.str.contains('random')]

# %%
all_data.sort_values(by = 'MAE')
# Out:
#        LOSS       MAE       MSE  RANDOM MAE  RANDOM MSE   \
# 0  1.431947  1.431946  3.968184    2.553878     8.945364
# 0  1.444038  1.444038  3.985211    2.553878     8.945364
# 0  1.466987  1.466988  4.108314    2.553878     8.945364
# 0  1.467538  1.467538  4.091740    2.553878     8.945364
# 0  1.709320  1.709320  5.490693    2.553878     8.945364
# 0  1.796295  1.796295  6.063594    2.553878     8.945364
# 0  2.477776  2.477776  9.114922    2.553878     8.945364
# 0  2.519843  2.519843  9.108214    2.553878     8.945364
# 0  2.522767  2.522767  9.064260    2.553878     8.945364
# 0  2.522835  2.522833  9.063444    2.553878     8.945364
# 0  2.523809  2.523808  9.051927    2.553878     8.945364
# 0  2.526413  2.526413  9.026658    2.553878     8.945364
# 0  2.526416  2.526417  9.026627    2.553878     8.945364
# 0  2.529900  2.529900  9.001388    2.553878     8.945364
# 0  2.531506  2.531507  8.992415    2.553878     8.945364
# ...

# %% [markdown]
# ### Context ONly

# %%
test_perf_path = '/mnt/g/mmsynergy/model/tune/context_only/comment/checkpoints/test/'
paths = [test_perf_path+i for i in os.listdir(test_perf_path)]
names = []
all_data = []
for p in paths:
    name = p.split('/')[-1].split('_seq')[0]
    data = torch.load(p)
    data = pd.DataFrame([data])
    data['name'] = name
    all_data.append(data)

all_data = pd.concat(all_data)
all_data = all_data.loc[:, ~all_data.columns.str.contains('random')]
# all_data['improved_mae'] = (all_data['MAE']-all_data['RANDOM MAE'])/all_data['RANDOM MAE']
# all_data['improved_mse'] = (all_data['MSE']-all_data['RANDOM MSE '])/all_data['RANDOM MSE ']
# all_data['RMSE'] = np.sqrt(all_data['MSE'])
# all_data['RANDOM RMSE'] = np.sqrt(all_data['RANDOM MSE '])
# all_data['improved_rmse'] = (all_data['RMSE']-all_data['RANDOM RMSE'])/all_data['RANDOM RMSE']
# all_data.sort_values(by = 'MAE')

# %%
all_data.sort_values(by = 'MAE')
# Out:
#         MAE       MSE      RMSE          MAPE        R2  \
# 0  1.388118  3.418304  1.848866  9.050356e+14  0.352042
# 0  1.389234  3.374030  1.836853  9.376132e+14  0.360435
# 0  1.392422  3.404660  1.845172  9.796643e+14  0.354629
# 0  1.556628  4.032994  2.008231  1.200695e+15  0.235525
# 0  1.633689  4.445052  2.108329  1.143526e+15  0.157417
# 0  1.835653  5.322913  2.307144  1.527369e+15 -0.008986
# 0  1.877058  5.434511  2.331204  1.654802e+15 -0.030140
# 0  1.877366  5.432744  2.330825  1.658958e+15 -0.029805
# 0  1.877423  5.466065  2.337962  1.630582e+15 -0.036121
# 0  1.877472  5.429370  2.330101  1.661007e+15 -0.029166
# 0  1.877836  5.437301  2.331802  1.658103e+15 -0.030669
# 0  1.877841  5.433958  2.331085  1.661944e+15 -0.030035
# 0  1.878097  5.434167  2.331130  1.660328e+15 -0.030075
# 0  1.878621  5.495939  2.344342  1.616343e+15 -0.041784
# 0  1.879429  5.413535  2.326700  1.686734e+15 -0.026164
#
#                                               name
# ...

# %%
test_perf_path = '/mnt/g/mmsynergy/model/tune/context_only/digg/checkpoints/test/'
paths = [test_perf_path+i for i in os.listdir(test_perf_path)]
names = []
all_data = []
for p in paths:
    name = p.split('/')[-1].split('_seq')[0]
    data = torch.load(p)
    data = pd.DataFrame([data])
    data['name'] = name
    all_data.append(data)

all_data = pd.concat(all_data)
all_data = all_data.loc[:, ~all_data.columns.str.contains('random')]
# all_data['improved_mae'] = (all_data['MAE']-all_data['RANDOM MAE'])/all_data['RANDOM MAE']
# all_data['improved_mse'] = (all_data['MSE']-all_data['RANDOM MSE '])/all_data['RANDOM MSE ']
# all_data['RMSE'] = np.sqrt(all_data['MSE'])
# all_data['RANDOM RMSE'] = np.sqrt(all_data['RANDOM MSE '])
# all_data['improved_rmse'] = (all_data['RMSE']-all_data['RANDOM RMSE'])/all_data['RANDOM RMSE']
# all_data.sort_values(by = 'MAE')

# %%
all_data.sort_values(by = 'MAE')
# Out:
#         MAE       MSE      RMSE          MAPE        R2  \
# 0  1.630797  5.119240  2.262574  9.708284e+12  0.445428
# 0  1.640369  5.216023  2.283862  9.877839e+12  0.434943
# 0  1.647732  5.234731  2.287953  9.645683e+12  0.432917
# 0  1.659389  5.308946  2.304115  1.040887e+13  0.424877
# 0  1.699474  5.229880  2.286893  1.075967e+13  0.433442
# 0  2.533860  9.775471  3.126575  1.091765e+13 -0.058986
# 0  2.534374  9.758266  3.123822  1.096330e+13 -0.057122
# 0  2.534949  9.714495  3.116808  1.100091e+13 -0.052381
# 0  2.535645  9.677421  3.110855  1.112226e+13 -0.048364
# 0  2.535699  9.654798  3.107217  1.113524e+13 -0.045914
# 0  2.536866  9.717124  3.117230  1.105640e+13 -0.052665
# 0  2.536885  9.689501  3.112796  1.114369e+13 -0.049673
# 0  2.537460  9.631698  3.103498  1.113428e+13 -0.043411
# 0  2.538433  9.588929  3.096600  1.116670e+13 -0.038778
# 0  2.538561  9.635260  3.104071  1.109113e+13 -0.043797
#
#                                               name
# ...

# %%
test_perf_path = '/mnt/g/mmsynergy/model/tune/context_only/play/checkpoints/test/'
paths = [test_perf_path+i for i in os.listdir(test_perf_path)]
names = []
all_data = []
for p in paths:
    name = p.split('/')[-1].split('_seq')[0]
    data = torch.load(p)
    data = pd.DataFrame([data])
    data['name'] = name
    all_data.append(data)

all_data = pd.concat(all_data)
all_data = all_data.loc[:, ~all_data.columns.str.contains('random')]

# %%
all_data.sort_values(by = 'MAE')
# Out:
#         MAE       MSE      RMSE      MAPE        R2  \
# 0  1.667532  5.183022  2.276625  0.206280  0.420591
# 0  1.671776  5.104866  2.259395  0.199875  0.429328
# 0  1.672415  5.129034  2.264737  0.204231  0.426627
# 0  1.673395  5.206587  2.281795  0.202093  0.417957
# 0  1.682219  5.156536  2.270801  0.202458  0.423552
# 0  1.689723  5.208877  2.282296  0.207672  0.417701
# 0  2.515543  9.294146  3.048630  0.296220 -0.038990
# 0  2.515967  9.211498  3.035045  0.298850 -0.029751
# 0  2.516219  9.334309  3.055210  0.295295 -0.043480
# 0  2.517161  9.277539  3.045905  0.297337 -0.037134
# 0  2.517297  9.290429  3.048021  0.296772 -0.038575
# 0  2.518528  9.240697  3.039851  0.298789 -0.033015
# 0  2.518946  9.384612  3.063432  0.294619 -0.049103
# 0  2.518977  9.362472  3.059816  0.295555 -0.046628
# 0  2.519648  9.558389  3.091664  0.290015 -0.068530
# 0  2.519669  9.335769  3.055449  0.296497 -0.043643
#
#                                               name
# ...

# %% [markdown]
# ### MulT-MTL-Contextual-structured

# %%
test_perf_path = '/mnt/g/mmsynergy/model/tune/mult_mtl_contextual_structured/checkpoints/test/'
paths = [test_perf_path+i for i in os.listdir(test_perf_path)]
names = []
all_data = []
for p in paths:
    name = p.split('/')[-1].split('_seq')[0]
    data = torch.load(p)
    data = pd.DataFrame([data])
    data['name'] = name
    all_data.append(data)

all_data = pd.concat(all_data)
all_data = all_data.loc[:, ~all_data.columns.str.contains('random')]

# %% [markdown]
# all_data

# %%
all_data[all_data['name'].str.contains("lr0.0005")].sort_values(by = 'test_total_loss')
# Out:
#    test_play_loss  test_shallow_loss  test_deep_loss  test_total_loss  \
# 0        1.389176           1.328268        1.183605         1.288675
# 0        1.377619           1.333074        1.183854         1.291204
# 0        1.417311           1.334498        1.187563         1.292287
# 0        1.393221           1.334037        1.193075         1.295407
# 0        1.420686           1.347708        1.205505         1.298124
# 0        1.428661           1.358119        1.192124         1.298776
# 0        1.397418           1.341246        1.195319         1.299727
# 0        1.393959           1.363380        1.191169         1.300612
# 0        1.423099           1.332474        1.208002         1.300810
# 0        1.417010           1.346349        1.203147         1.303200
# 0        1.413858           1.356899        1.199606         1.305374
# 0        1.389769           1.348835        1.193540         1.307184
# ...

# %% [markdown]
# ## MulT-MTL-Contextual

# %%
test_perf_path = '/mnt/f/erya/mmsynergy/model/tune/mtl/checkpoints/test/'
paths = [test_perf_path+i for i in os.listdir(test_perf_path)]
names = []
all_data = []
for p in paths:
    name = p.split('/')[-1].split('_seq')[0]
    data = torch.load(p)
    data = pd.DataFrame([data])
    data['name'] = name
    all_data.append(data)

all_data = pd.concat(all_data)
all_data = all_data.loc[:, ~all_data.columns.str.contains('random')]
# all_data['improved_mae'] = (all_data['MAE']-all_data['RANDOM MAE'])/all_data['RANDOM MAE']
# all_data['improved_mse'] = (all_data['MSE']-all_data['RANDOM MSE '])/all_data['RANDOM MSE ']
# all_data['RMSE'] = np.sqrt(all_data['MSE'])
# all_data['RANDOM RMSE'] = np.sqrt(all_data['RANDOM MSE '])
# all_data['improved_rmse'] = (all_data['RMSE']-all_data['RANDOM RMSE'])/all_data['RANDOM RMSE']
# all_data.sort_values(by = 'MAE')

# %%
all_data.sort_values(by = 'test_total_loss')
# Out:
#    test_play_loss  test_shallow_loss  test_deep_loss  test_total_loss  \
# 0        1.381830           1.323138        1.176598         1.337830
# 0        1.386153           1.322959        1.171202         1.339381
# 0        1.384185           1.328905        1.181862         1.341841
# 0        1.396600           1.325772        1.187276         1.347336
# 0        1.401184           1.323798        1.172971         1.347408
# 0        1.398320           1.338302        1.184894         1.352970
# 0        1.403142           1.332919        1.187402         1.353479
# 0        1.403212           1.334509        1.182536         1.353663
# 0        1.409877           1.327554        1.181044         1.354064
# 0        1.404203           1.335101        1.183733         1.354515
# 0        1.402362           1.336598        1.188153         1.354636
# 0        1.394956           1.347073        1.195388         1.355846
# ...

# %% [markdown]
# ## MulT-MTL

# %%
test_perf_path = '/mnt/g/mmsynergy/model/tune/mult_mtl/checkpoints/test/'
paths = [test_perf_path+i for i in os.listdir(test_perf_path)]
names = []
all_data = []
for p in paths:
    name = p.split('/')[-1].split('_seq')[0]
    data = torch.load(p)
    data = pd.DataFrame([data])
    data['name'] = name
    all_data.append(data)

all_data = pd.concat(all_data)
all_data = all_data.loc[:, ~all_data.columns.str.contains('random')]
# all_data['improved_mae'] = (all_data['MAE']-all_data['RANDOM MAE'])/all_data['RANDOM MAE']
# all_data['improved_mse'] = (all_data['MSE']-all_data['RANDOM MSE '])/all_data['RANDOM MSE ']
# all_data['RMSE'] = np.sqrt(all_data['MSE'])
# all_data['RANDOM RMSE'] = np.sqrt(all_data['RANDOM MSE '])
# all_data['improved_rmse'] = (all_data['RMSE']-all_data['RANDOM RMSE'])/all_data['RANDOM RMSE']
# all_data.sort_values(by = 'MAE')

# %%
all_data.sort_values(by = 'test_total_loss')
# Out:
#    test_play_loss  test_shallow_loss  test_deep_loss  test_total_loss  \
# 0        1.734714           1.717061        1.416075         1.695789
# 0        1.746929           1.731957        1.419569         1.708204
# 0        1.750841           1.728932        1.413189         1.708312
# 0        1.751963           1.734452        1.417793         1.711542
# 0        1.756731           1.735401        1.419899         1.714516
# 0        1.758480           1.736673        1.420078         1.715917
# 0        1.759176           1.738201        1.427999         1.717668
# 0        1.764373           1.735252        1.420160         1.718303
# 0        1.756881           1.744753        1.422421         1.718584
# 0        1.760127           1.740354        1.425998         1.718805
# 0        1.759721           1.742520        1.434506         1.720319
# 0        1.760939           1.747712        1.425672         1.722122
# ...

# %%
(1.176-1.418)/1.418
# Out:
# -0.17066290550070523

# %% [markdown]
# ### MulT-Comment

# %%
test_perf_path = '/mnt/g/mmsynergy/model/tune/mult_comment/checkpoints/test/'
paths = [test_perf_path+i for i in os.listdir(test_perf_path)]
names = []
all_data = []
for p in paths:
    name = p.split('/')[-1].split('_seq')[0]
    data = torch.load(p)
    data = pd.DataFrame([data])
    data['name'] = name
    all_data.append(data)

all_data = pd.concat(all_data)
all_data = all_data.loc[:, ~all_data.columns.str.contains('random')]

# %%
all_data.sort_values(by = 'MAE')
# Out:
#        LOSS       MAE       MSE  RANDOM MAE  RANDOM MSE   \
# 0  1.419022  1.419022  3.540674    1.901197     5.257416
# 0  1.421657  1.421658  3.490895    1.901197     5.257416
# 0  1.421945  1.421944  3.516845    1.901197     5.257416
# 0  1.423528  1.423528  3.448634    1.901197     5.257416
# 0  1.424634  1.424634  3.546115    1.901197     5.257416
# 0  1.430784  1.430784  3.566396    1.901197     5.257416
# 0  1.440979  1.440979  3.629177    1.901197     5.257416
# 0  1.443056  1.443056  3.522136    1.901197     5.257416
# 0  1.466886  1.466886  3.603528    1.901197     5.257416
# 0  1.474601  1.474601  3.791961    1.901197     5.257416
# 0  1.485970  1.485970  3.827686    1.901197     5.257416
# 0  1.589364  1.589364  4.274573    1.901197     5.257416
#
#                      name
# 0   perf_lr0.0005_bs64.pt
# 0    perf_lr0.001_bs64.pt
# 0    perf_lr0.001_bs32.pt
# 0   perf_lr0.0005_bs16.pt
# 0   perf_lr0.0005_bs32.pt
# 0    perf_lr0.001_bs16.pt
# 0  perf_lr0.0005_bs128.pt
# ...

# %%
test_perf_path = '/mnt/g/mmsynergy/model/tune/mult_digg/checkpoints/test/'
paths = [test_perf_path+i for i in os.listdir(test_perf_path)]
names = []
all_data = []
for p in paths:
    name = p.split('/')[-1].split('_seq')[0]
    data = torch.load(p)
    data = pd.DataFrame([data])
    data['name'] = name
    all_data.append(data)

all_data = pd.concat(all_data)
all_data = all_data.loc[:, ~all_data.columns.str.contains('random')]
# all_data['improved_mae'] = (all_data['MAE']-all_data['RANDOM MAE'])/all_data['RANDOM MAE']
# all_data['improved_mse'] = (all_data['MSE']-all_data['RANDOM MSE '])/all_data['RANDOM MSE ']
# all_data['RMSE'] = np.sqrt(all_data['MSE'])
# all_data['RANDOM RMSE'] = np.sqrt(all_data['RANDOM MSE '])
# all_data['improved_rmse'] = (all_data['RMSE']-all_data['RANDOM RMSE'])/all_data['RANDOM RMSE']
# all_data.sort_values(by = 'MAE')

# %%
all_data.sort_values(by = 'MAE')
# Out:
#        LOSS       MAE       MSE  RANDOM MAE  RANDOM MSE   \
# 0  1.724516  1.724516  5.923147    2.604568     9.257863
# 0  1.724524  1.724524  5.679878    2.604568     9.257863
# 0  1.728177  1.728176  5.728606    2.604568     9.257863
# 0  1.735806  1.735806  6.065901    2.604568     9.257863
# 0  1.737687  1.737687  5.958507    2.604568     9.257863
# 0  1.739552  1.739552  5.843442    2.604568     9.257863
# 0  1.748829  1.748828  5.651752    2.604568     9.257863
# 0  1.752701  1.752700  5.793352    2.604568     9.257863
# 0  1.754050  1.754049  6.116523    2.604568     9.257863
# 0  1.776644  1.776643  6.248326    2.604568     9.257863
# 0  1.801820  1.801821  6.375791    2.604568     9.257863
# 0  2.029541  2.029542  7.193974    2.604568     9.257863
#
#                      name
# 0   perf_lr0.0005_bs16.pt
# 0   perf_lr0.001_bs128.pt
# 0    perf_lr0.001_bs32.pt
# 0  perf_lr0.0005_bs128.pt
# 0   perf_lr0.0005_bs64.pt
# 0    perf_lr0.001_bs64.pt
# 0    perf_lr0.001_bs16.pt
# ...

# %%
test_perf_path = '/mnt/g/mmsynergy/model/tune/mult_play/checkpoints/test/'
paths = [test_perf_path+i for i in os.listdir(test_perf_path)]
names = []
all_data = []
for p in paths:
    name = p.split('/')[-1].split('_seq')[0]
    data = torch.load(p)
    data = pd.DataFrame([data])
    data['name'] = name
    all_data.append(data)

all_data = pd.concat(all_data)
all_data = all_data.loc[:, ~all_data.columns.str.contains('random')]

# %%
all_data.sort_values(by = 'MAE')
# Out:
#        LOSS       MAE       MSE  RANDOM MAE  RANDOM MSE   \
# 0  1.736761  1.736761  5.588111    2.563402     8.938459
# 0  1.749451  1.749451  5.647393    2.563402     8.938459
# 0  1.756462  1.756461  5.815392    2.563402     8.938459
# 0  1.756464  1.756464  5.633431    2.563402     8.938459
# 0  1.765619  1.765620  5.707147    2.563402     8.938459
# 0  1.767282  1.767282  5.726552    2.563402     8.938459
# 0  1.769869  1.769869  5.714252    2.563402     8.938459
# 0  1.775585  1.775585  5.980696    2.563402     8.938459
# 0  1.809629  1.809629  6.081167    2.563402     8.938459
# 0  1.817187  1.817188  6.178234    2.563402     8.938459
# 0  1.840690  1.840690  5.825597    2.563402     8.938459
# 0  2.045465  2.045466  7.039365    2.563402     8.938459
#
#                      name
# 0    perf_lr0.001_bs16.pt
# 0    perf_lr0.001_bs64.pt
# 0   perf_lr0.0005_bs16.pt
# 0   perf_lr0.0005_bs64.pt
# 0    perf_lr0.001_bs32.pt
# 0  perf_lr0.0005_bs128.pt
# 0   perf_lr0.001_bs128.pt
# ...

# %% [markdown]
# ### MULT-NO CMT

# %%
test_perf_path = '/mnt/g/mmsynergy/model/tune/mult_nocmt/comment_nocmt/checkpoints/test/'
paths = [test_perf_path+i for i in os.listdir(test_perf_path)]
names = []
all_data = []
for p in paths:
    name = p.split('/')[-1].split('_seq')[0]
    data = torch.load(p)
    data = pd.DataFrame([data])
    data['name'] = name
    all_data.append(data)

all_data = pd.concat(all_data)
all_data = all_data.loc[:, ~all_data.columns.str.contains('random')]
# all_data['improved_mae'] = (all_data['MAE']-all_data['RANDOM MAE'])/all_data['RANDOM MAE']
# all_data['improved_mse'] = (all_data['MSE']-all_data['RANDOM MSE '])/all_data['RANDOM MSE ']
# all_data['RMSE'] = np.sqrt(all_data['MSE'])
# all_data['RANDOM RMSE'] = np.sqrt(all_data['RANDOM MSE '])
# all_data['improved_rmse'] = (all_data['RMSE']-all_data['RANDOM RMSE'])/all_data['RANDOM RMSE']
# all_data.sort_values(by = 'MAE')

# %%
all_data.sort_values(by = 'MAE')
# Out:
#         MAE       MSE  RANDOM MAE  RANDOM MSE                     name
# 0  1.421586  3.580266    1.901197     5.257416   perf_lr0.0005_bs32.pt
# 0  1.423464  3.575373    1.901197     5.257416    perf_lr0.001_bs32.pt
# 0  1.425245  3.614957    1.901197     5.257416  perf_lr0.0005_bs128.pt
# 0  1.427688  3.522494    1.901197     5.257416   perf_lr0.001_bs128.pt
# 0  1.430194  3.562675    1.901197     5.257416    perf_lr0.001_bs16.pt
# 0  1.434315  3.600397    1.901197     5.257416    perf_lr0.001_bs64.pt
# 0  1.435250  3.629471    1.901197     5.257416   perf_lr0.0005_bs16.pt
# 0  1.440231  3.631775    1.901197     5.257416   perf_lr0.0005_bs64.pt
# 0  1.445253  3.635866    1.901197     5.257416   perf_lr0.0001_bs64.pt
# 0  1.454792  3.648659    1.901197     5.257416    perf_lr0.005_bs64.pt

# %%
test_perf_path = '/mnt/g/mmsynergy/model/tune/mult_nocmt/digg_nocmt/checkpoints/test/'
paths = [test_perf_path+i for i in os.listdir(test_perf_path)]
names = []
all_data = []
for p in paths:
    name = p.split('/')[-1].split('_seq')[0]
    data = torch.load(p)
    data = pd.DataFrame([data])
    data['name'] = name
    all_data.append(data)

all_data = pd.concat(all_data)
all_data = all_data.loc[:, ~all_data.columns.str.contains('random')]

# %%
all_data.sort_values(by = 'MAE')
# Out:
#         MAE       MSE  RANDOM MAE  RANDOM MSE                     name
# 0  1.722117  5.935918    2.604568     9.257863    perf_lr0.001_bs32.pt
# 0  1.728183  5.811798    2.604568     9.257863    perf_lr0.001_bs64.pt
# 0  1.740796  6.028658    2.604568     9.257863  perf_lr0.0005_bs128.pt
# 0  1.743250  5.850752    2.604568     9.257863    perf_lr0.001_bs16.pt
# 0  1.744309  5.953280    2.604568     9.257863   perf_lr0.001_bs128.pt
# 0  1.744814  5.893410    2.604568     9.257863   perf_lr0.0005_bs64.pt
# 0  1.745166  5.976555    2.604568     9.257863   perf_lr0.0005_bs32.pt
# 0  1.752146  6.002500    2.604568     9.257863   perf_lr0.0005_bs16.pt
# 0  1.762806  6.094113    2.604568     9.257863   perf_lr0.0001_bs64.pt
# 0  1.770122  5.998705    2.604568     9.257863    perf_lr0.005_bs64.pt

# %%
test_perf_path = '/mnt/g/mmsynergy/model/tune/mult_nocmt/play_nocmt/checkpoints/test/'
paths = [test_perf_path+i for i in os.listdir(test_perf_path)]
names = []
all_data = []
for p in paths:
    name = p.split('/')[-1].split('_seq')[0]
    data = torch.load(p)
    data = pd.DataFrame([data])
    data['name'] = name
    all_data.append(data)

all_data = pd.concat(all_data)
all_data = all_data.loc[:, ~all_data.columns.str.contains('random')]
# all_data['improved_mae'] = (all_data['MAE']-all_data['RANDOM MAE'])/all_data['RANDOM MAE']
# all_data['improved_mse'] = (all_data['MSE']-all_data['RANDOM MSE '])/all_data['RANDOM MSE ']
# all_data['RMSE'] = np.sqrt(all_data['MSE'])
# all_data['RANDOM RMSE'] = np.sqrt(all_data['RANDOM MSE '])
# all_data['improved_rmse'] = (all_data['RMSE']-all_data['RANDOM RMSE'])/all_data['RANDOM RMSE']
# all_data.sort_values(by = 'MAE')

# %%
all_data.sort_values(by = 'MAE')
# Out:
#         MAE       MSE  RANDOM MAE  RANDOM MSE                     name
# 0  1.740782  5.625556    2.563402     8.938459   perf_lr0.0005_bs16.pt
# 0  1.747067  5.605251    2.563402     8.938459   perf_lr0.001_bs128.pt
# 0  1.748125  5.626380    2.563402     8.938459    perf_lr0.001_bs16.pt
# 0  1.759144  5.779203    2.563402     8.938459    perf_lr0.001_bs64.pt
# 0  1.762929  5.739812    2.563402     8.938459   perf_lr0.0005_bs32.pt
# 0  1.770663  5.642751    2.563402     8.938459   perf_lr0.005_bs128.pt
# 0  1.771546  5.939111    2.563402     8.938459   perf_lr0.0005_bs64.pt
# 0  1.775235  5.869123    2.563402     8.938459   perf_lr0.0001_bs32.pt
# 0  1.775499  5.738451    2.563402     8.938459    perf_lr0.005_bs32.pt
# 0  1.777813  5.951662    2.563402     8.938459  perf_lr0.0005_bs128.pt
# 0  1.778290  5.839773    2.563402     8.938459   perf_lr0.0001_bs16.pt
# 0  1.780657  5.760149    2.563402     8.938459  perf_lr0.0001_bs128.pt
# ...

# %% [markdown]
# ### UNimodal A

# %%
test_perf_path = '/mnt/g/mmsynergy/model/tune/uni_a/comment/checkpoints/test/'
paths = [test_perf_path+i for i in os.listdir(test_perf_path)]
names = []
all_data = []
for p in paths:
    name = p.split('/')[-1].split('_seq')[0]
    data = torch.load(p)
    data = pd.DataFrame([data])
    data['name'] = name
    all_data.append(data)

all_data = pd.concat(all_data)
all_data = all_data.loc[:, ~all_data.columns.str.contains('random')]
# all_data['improved_mae'] = (all_data['MAE']-all_data['RANDOM MAE'])/all_data['RANDOM MAE']
# all_data['improved_mse'] = (all_data['MSE']-all_data['RANDOM MSE '])/all_data['RANDOM MSE ']
# all_data['RMSE'] = np.sqrt(all_data['MSE'])
# all_data['RANDOM RMSE'] = np.sqrt(all_data['RANDOM MSE '])
# all_data['improved_rmse'] = (all_data['RMSE']-all_data['RANDOM RMSE'])/all_data['RANDOM RMSE']
# all_data.sort_values(by = 'MAE')

# %%
all_data.sort_values(by = 'MAE')
# Out:
#         MAE       MSE  RANDOM MAE  RANDOM MSE   \
# 0  1.447293  3.594232    1.901197     5.257416
# 0  1.451051  3.642016    1.901197     5.257416
# 0  1.456618  3.657260    1.901197     5.257416
# 0  1.465319  3.653127    1.901197     5.257416
# 0  1.466956  3.709956    1.901197     5.257416
# 0  1.868709  5.383795    1.901197     5.257416
# 0  1.878909  5.412381    1.901197     5.257416
# 0  1.878970  5.423249    1.901197     5.257416
# 0  1.878983  5.410527    1.901197     5.257416
# 0  1.879203  5.429916    1.901197     5.257416
# 0  1.879481  5.420660    1.901197     5.257416
# 0  1.879582  5.405553    1.901197     5.257416
# 0  1.879662  5.458250    1.901197     5.257416
# 0  1.879694  5.429055    1.901197     5.257416
# 0  1.879755  5.435772    1.901197     5.257416
# 0  1.880143  5.459075    1.901197     5.257416
# 0  1.880246  5.448557    1.901197     5.257416
# 0  1.880457  5.450042    1.901197     5.257416
# 0  1.880567  5.463206    1.901197     5.257416
# ...

# %%
test_perf_path = '/mnt/g/mmsynergy/model/tune/uni_a/digg/checkpoints/test/'
paths = [test_perf_path+i for i in os.listdir(test_perf_path)]
names = []
all_data = []
for p in paths:
    name = p.split('/')[-1].split('_seq')[0]
    data = torch.load(p)
    data = pd.DataFrame([data])
    data['name'] = name
    all_data.append(data)

all_data = pd.concat(all_data)
all_data = all_data.loc[:, ~all_data.columns.str.contains('random')]
# all_data['improved_mae'] = (all_data['MAE']-all_data['RANDOM MAE'])/all_data['RANDOM MAE']
# all_data['improved_mse'] = (all_data['MSE']-all_data['RANDOM MSE '])/all_data['RANDOM MSE ']
# all_data['RMSE'] = np.sqrt(all_data['MSE'])
# all_data['RANDOM RMSE'] = np.sqrt(all_data['RANDOM MSE '])
# all_data['improved_rmse'] = (all_data['RMSE']-all_data['RANDOM RMSE'])/all_data['RANDOM RMSE']
# all_data.sort_values(by = 'MAE')

# %%
all_data.sort_values(by = 'MAE')
# Out:
#         MAE        MSE  RANDOM MAE  RANDOM MSE   \
# 0  1.779671   6.077357    2.604568     9.257863
# 0  1.784962   5.929298    2.604568     9.257863
# 0  1.798408   6.040776    2.604568     9.257863
# 0  1.801869   6.155090    2.604568     9.257863
# 0  2.499372   9.026345    2.604568     9.257863
# 0  2.547153   9.677636    2.604568     9.257863
# 0  2.547803   9.783060    2.604568     9.257863
# 0  2.548310   9.729877    2.604568     9.257863
# 0  2.548444   9.703801    2.604568     9.257863
# 0  2.548507   9.758516    2.604568     9.257863
# 0  2.548969   9.800871    2.604568     9.257863
# 0  2.549085   9.730039    2.604568     9.257863
# 0  2.549088   9.779908    2.604568     9.257863
# 0  2.549514   9.717133    2.604568     9.257863
# 0  2.549979   9.671098    2.604568     9.257863
# 0  2.550855   9.763712    2.604568     9.257863
# 0  2.552466   9.889875    2.604568     9.257863
# 0  2.553029   9.703080    2.604568     9.257863
# ...

# %%
test_perf_path = '/mnt/g/mmsynergy/model/tune/uni_a/play/checkpoints/test/'
paths = [test_perf_path+i for i in os.listdir(test_perf_path)]
names = []
all_data = []
for p in paths:
    name = p.split('/')[-1].split('_seq')[0]
    data = torch.load(p)
    data = pd.DataFrame([data])
    data['name'] = name
    all_data.append(data)

all_data = pd.concat(all_data)
all_data = all_data.loc[:, ~all_data.columns.str.contains('random')]
# all_data['improved_mae'] = (all_data['MAE']-all_data['RANDOM MAE'])/all_data['RANDOM MAE']
# all_data['improved_mse'] = (all_data['MSE']-all_data['RANDOM MSE '])/all_data['RANDOM MSE ']
# all_data['RMSE'] = np.sqrt(all_data['MSE'])
# all_data['RANDOM RMSE'] = np.sqrt(all_data['RANDOM MSE '])
# all_data['improved_rmse'] = (all_data['RMSE']-all_data['RANDOM RMSE'])/all_data['RANDOM RMSE']
# all_data.sort_values(by = 'MAE')

# %%
all_data.sort_values(by = 'MAE')
# Out:
#         MAE       MSE  RANDOM MAE  RANDOM MSE   \
# 0  1.794934  5.851958    2.563402     8.938459
# 0  1.807714  5.990745    2.563402     8.938459
# 0  1.812187  6.065843    2.563402     8.938459
# 0  1.818944  6.085917    2.563402     8.938459
# 0  1.819909  5.975746    2.563402     8.938459
# 0  1.842818  6.136201    2.563402     8.938459
# 0  2.512185  9.219532    2.563402     8.938459
# 0  2.527357  9.310624    2.563402     8.938459
# 0  2.527927  9.276772    2.563402     8.938459
# 0  2.528056  9.298508    2.563402     8.938459
# 0  2.528335  9.339790    2.563402     8.938459
# 0  2.528578  9.333484    2.563402     8.938459
# 0  2.529033  9.329350    2.563402     8.938459
# 0  2.529629  9.226208    2.563402     8.938459
# 0  2.529807  9.453038    2.563402     8.938459
# 0  2.530259  9.255385    2.563402     8.938459
# 0  2.530433  9.142639    2.563402     8.938459
# 0  2.531816  9.354991    2.563402     8.938459
# 0  2.534510  9.296262    2.563402     8.938459
# ...

# %% [markdown]
# ### Uni V

# %%
test_perf_path = '/mnt/g/mmsynergy/model/tune/uni_v/comment/checkpoints/test/'
paths = [test_perf_path+i for i in os.listdir(test_perf_path)]
names = []
all_data = []
for p in paths:
    name = p.split('/')[-1].split('_seq')[0]
    data = torch.load(p)
    data = pd.DataFrame([data])
    data['name'] = name
    all_data.append(data)

all_data = pd.concat(all_data)
all_data = all_data.loc[:, ~all_data.columns.str.contains('random')]
# all_data['improved_mae'] = (all_data['MAE']-all_data['RANDOM MAE'])/all_data['RANDOM MAE']
# all_data['improved_mse'] = (all_data['MSE']-all_data['RANDOM MSE '])/all_data['RANDOM MSE ']
# all_data['RMSE'] = np.sqrt(all_data['MSE'])
# all_data['RANDOM RMSE'] = np.sqrt(all_data['RANDOM MSE '])
# all_data['improved_rmse'] = (all_data['RMSE']-all_data['RANDOM RMSE'])/all_data['RANDOM RMSE']
# all_data.sort_values(by = 'MAE')

# %%
all_data.sort_values(by = 'MAE')
# Out:
#         MAE       MSE  RANDOM MAE  RANDOM MSE   \
# 0  1.786882  5.066194    1.901197     5.257416
# 0  1.806396  5.168913    1.901197     5.257416
# 0  1.876168  5.459413    1.901197     5.257416
# 0  1.878623  5.424831    1.901197     5.257416
# 0  1.878650  5.408046    1.901197     5.257416
# 0  1.878906  5.400383    1.901197     5.257416
# 0  1.879007  5.446267    1.901197     5.257416
# 0  1.879017  5.416008    1.901197     5.257416
# 0  1.879075  5.422038    1.901197     5.257416
# 0  1.879363  5.390932    1.901197     5.257416
# 0  1.879400  5.418875    1.901197     5.257416
# 0  1.879495  5.431852    1.901197     5.257416
# 0  1.879658  5.425710    1.901197     5.257416
# 0  1.879672  5.446935    1.901197     5.257416
# 0  1.879844  5.445699    1.901197     5.257416
# 0  1.880012  5.448524    1.901197     5.257416
# 0  1.880136  5.440206    1.901197     5.257416
# 0  1.880175  5.454734    1.901197     5.257416
# 0  1.880180  5.460726    1.901197     5.257416
# ...

# %%
test_perf_path = '/mnt/g/mmsynergy/model/tune/uni_v/digg/checkpoints/test/'
paths = [test_perf_path+i for i in os.listdir(test_perf_path)]
names = []
all_data = []
for p in paths:
    name = p.split('/')[-1].split('_seq')[0]
    data = torch.load(p)
    data = pd.DataFrame([data])
    data['name'] = name
    all_data.append(data)

all_data = pd.concat(all_data)
all_data = all_data.loc[:, ~all_data.columns.str.contains('random')]
# all_data['improved_mae'] = (all_data['MAE']-all_data['RANDOM MAE'])/all_data['RANDOM MAE']
# all_data['improved_mse'] = (all_data['MSE']-all_data['RANDOM MSE '])/all_data['RANDOM MSE ']
# all_data['RMSE'] = np.sqrt(all_data['MSE'])
# all_data['RANDOM RMSE'] = np.sqrt(all_data['RANDOM MSE '])
# all_data['improved_rmse'] = (all_data['RMSE']-all_data['RANDOM RMSE'])/all_data['RANDOM RMSE']
# all_data.sort_values(by = 'MAE')

# %%
all_data.sort_values(by = 'MAE')
# Out:
#         MAE        MSE  RANDOM MAE  RANDOM MSE   \
# 0  2.377986   9.052855    2.604568     9.257863
# 0  2.401178   9.072220    2.604568     9.257863
# 0  2.405240   8.934927    2.604568     9.257863
# 0  2.505190   9.462035    2.604568     9.257863
# 0  2.528848   9.740750    2.604568     9.257863
# 0  2.547672   9.833224    2.604568     9.257863
# 0  2.548099   9.778241    2.604568     9.257863
# 0  2.548190   9.841286    2.604568     9.257863
# 0  2.548388   9.799336    2.604568     9.257863
# 0  2.548499   9.792518    2.604568     9.257863
# 0  2.548697   9.843009    2.604568     9.257863
# 0  2.549741   9.955504    2.604568     9.257863
# 0  2.550227   9.898696    2.604568     9.257863
# 0  2.550244   9.857384    2.604568     9.257863
# 0  2.550617   9.769636    2.604568     9.257863
# 0  2.550862   9.687618    2.604568     9.257863
# 0  2.550980   9.656542    2.604568     9.257863
# 0  2.552090   9.901988    2.604568     9.257863
# ...

# %%
test_perf_path = '/mnt/g/mmsynergy/model/tune/uni_v/play/checkpoints/test/'
paths = [test_perf_path+i for i in os.listdir(test_perf_path)]
names = []
all_data = []
for p in paths:
    name = p.split('/')[-1].split('_seq')[0]
    data = torch.load(p)
    data = pd.DataFrame([data])
    data['name'] = name
    all_data.append(data)

all_data = pd.concat(all_data)
all_data = all_data.loc[:, ~all_data.columns.str.contains('random')]

# %%
all_data.sort_values(by = 'MAE')
# Out:
#         MAE       MSE  RANDOM MAE  RANDOM MSE   \
# 0  2.325089  8.444767    2.563402     8.938459
# 0  2.326860  8.744307    2.563402     8.938459
# 0  2.340794  8.625060    2.563402     8.938459
# 0  2.367508  8.589175    2.563402     8.938459
# 0  2.523581  9.311892    2.563402     8.938459
# 0  2.527529  9.308545    2.563402     8.938459
# 0  2.527979  9.303797    2.563402     8.938459
# 0  2.528256  9.294982    2.563402     8.938459
# 0  2.528463  9.278079    2.563402     8.938459
# 0  2.528496  9.344318    2.563402     8.938459
# 0  2.528594  9.268806    2.563402     8.938459
# 0  2.528603  9.247916    2.563402     8.938459
# 0  2.528624  9.305679    2.563402     8.938459
# 0  2.528645  9.382632    2.563402     8.938459
# 0  2.529193  9.376472    2.563402     8.938459
# 0  2.529326  9.340847    2.563402     8.938459
# 0  2.529386  9.282303    2.563402     8.938459
# 0  2.529701  9.228246    2.563402     8.938459
# 0  2.532326  9.195398    2.563402     8.938459
# ...

# %% [markdown]
# ### EF

# %%
test_perf_path = '/mnt/g/mmsynergy/model/tune/ef/comment/checkpoints/test/'
paths = [test_perf_path+i for i in os.listdir(test_perf_path)]
names = []
all_data = []
for p in paths:
    name = p.split('/')[-1].split('_seq')[0]
    data = torch.load(p)
    data = pd.DataFrame([data])
    data['name'] = name
    all_data.append(data)

all_data = pd.concat(all_data)
all_data = all_data.loc[:, ~all_data.columns.str.contains('random')]
# all_data['improved_mae'] = (all_data['MAE']-all_data['RANDOM MAE'])/all_data['RANDOM MAE']
# all_data['improved_mse'] = (all_data['MSE']-all_data['RANDOM MSE '])/all_data['RANDOM MSE ']
# all_data['RMSE'] = np.sqrt(all_data['MSE'])
# all_data['RANDOM RMSE'] = np.sqrt(all_data['RANDOM MSE '])
# all_data['improved_rmse'] = (all_data['RMSE']-all_data['RANDOM RMSE'])/all_data['RANDOM RMSE']
# all_data.sort_values(by = 'MAE')

# %%
all_data.sort_values(by = 'MAE')
# Out:
#         MAE       MSE  RANDOM MAE  RANDOM MSE   \
# 0  1.431442  3.554189    1.901197     5.257416
# 0  1.431981  3.596942    1.901197     5.257416
# 0  1.442192  3.699993    1.901197     5.257416
# 0  1.442730  3.649181    1.901197     5.257416
# 0  1.447776  3.660818    1.901197     5.257416
# 0  1.451331  3.714575    1.901197     5.257416
# 0  1.451625  3.675710    1.901197     5.257416
# 0  1.465589  3.730356    1.901197     5.257416
# 0  1.465788  3.658027    1.901197     5.257416
# 0  1.477340  3.750658    1.901197     5.257416
# 0  1.862765  5.423551    1.901197     5.257416
# 0  1.878858  5.407162    1.901197     5.257416
# 0  1.878860  5.406773    1.901197     5.257416
# 0  1.878897  5.411822    1.901197     5.257416
# 0  1.878911  5.412648    1.901197     5.257416
# 0  1.879023  5.419196    1.901197     5.257416
# 0  1.879077  5.386639    1.901197     5.257416
# 0  1.879079  5.422571    1.901197     5.257416
# 0  1.879180  5.377589    1.901197     5.257416
# ...

# %%
test_perf_path = '/mnt/g/mmsynergy/model/tune/ef/digg/checkpoints/test/'
paths = [test_perf_path+i for i in os.listdir(test_perf_path)]
names = []
all_data = []
for p in paths:
    name = p.split('/')[-1].split('_seq')[0]
    data = torch.load(p)
    data = pd.DataFrame([data])
    data['name'] = name
    all_data.append(data)

all_data = pd.concat(all_data)
all_data = all_data.loc[:, ~all_data.columns.str.contains('random')]
# all_data['improved_mae'] = (all_data['MAE']-all_data['RANDOM MAE'])/all_data['RANDOM MAE']
# all_data['improved_mse'] = (all_data['MSE']-all_data['RANDOM MSE '])/all_data['RANDOM MSE ']
# all_data['RMSE'] = np.sqrt(all_data['MSE'])
# all_data['RANDOM RMSE'] = np.sqrt(all_data['RANDOM MSE '])
# all_data['improved_rmse'] = (all_data['RMSE']-all_data['RANDOM RMSE'])/all_data['RANDOM RMSE']
# all_data.sort_values(by = 'MAE')

# %%
all_data.sort_values(by = 'MAE')
# Out:
#         MAE       MSE  RANDOM MAE  RANDOM MSE   \
# 0  1.740148  5.990028    2.604568     9.257863
# 0  1.752908  6.004979    2.604568     9.257863
# 0  1.759092  5.963996    2.604568     9.257863
# 0  1.774899  5.933746    2.604568     9.257863
# 0  1.777914  6.172125    2.604568     9.257863
# 0  1.779668  6.139826    2.604568     9.257863
# 0  1.807889  6.103299    2.604568     9.257863
# 0  1.809204  6.176693    2.604568     9.257863
# 0  1.829868  6.210912    2.604568     9.257863
# 0  2.515945  9.578453    2.604568     9.257863
# 0  2.548100  9.788065    2.604568     9.257863
# 0  2.548122  9.759366    2.604568     9.257863
# 0  2.548276  9.841308    2.604568     9.257863
# 0  2.548570  9.689919    2.604568     9.257863
# 0  2.548783  9.672668    2.604568     9.257863
# 0  2.549261  9.643147    2.604568     9.257863
# 0  2.549395  9.634503    2.604568     9.257863
# 0  2.550100  9.605274    2.604568     9.257863
# 0  2.550241  9.599993    2.604568     9.257863
# ...

# %%
test_perf_path = '/mnt/g/mmsynergy/model/tune/ef/play/checkpoints/test/'
paths = [test_perf_path+i for i in os.listdir(test_perf_path)]
names = []
all_data = []
for p in paths:
    name = p.split('/')[-1].split('_seq')[0]
    data = torch.load(p)
    data = pd.DataFrame([data])
    data['name'] = name
    all_data.append(data)

all_data = pd.concat(all_data)
all_data = all_data.loc[:, ~all_data.columns.str.contains('random')]
# all_data['improved_mae'] = (all_data['MAE']-all_data['RANDOM MAE'])/all_data['RANDOM MAE']
# all_data['improved_mse'] = (all_data['MSE']-all_data['RANDOM MSE '])/all_data['RANDOM MSE ']
# all_data['RMSE'] = np.sqrt(all_data['MSE'])
# all_data['RANDOM RMSE'] = np.sqrt(all_data['RANDOM MSE '])
# all_data['improved_rmse'] = (all_data['RMSE']-all_data['RANDOM RMSE'])/all_data['RANDOM RMSE']
# all_data.sort_values(by = 'MAE')

# %%
all_data.sort_values(by = 'MAE')
# Out:
#         MAE       MSE  RANDOM MAE  RANDOM MSE   \
# 0  1.776598  5.983274    2.563402     8.938459
# 0  1.777741  5.952042    2.563402     8.938459
# 0  1.786456  6.012507    2.563402     8.938459
# 0  1.795373  6.015386    2.563402     8.938459
# 0  1.796953  5.947953    2.563402     8.938459
# 0  1.801968  5.873622    2.563402     8.938459
# 0  1.805137  6.015565    2.563402     8.938459
# 0  1.833086  6.142826    2.563402     8.938459
# 0  1.850468  6.196610    2.563402     8.938459
# 0  2.253563  8.271132    2.563402     8.938459
# 0  2.360084  8.360289    2.563402     8.938459
# 0  2.509029  8.964610    2.563402     8.938459
# 0  2.527512  9.301866    2.563402     8.938459
# 0  2.527524  9.307836    2.563402     8.938459
# 0  2.527572  9.323275    2.563402     8.938459
# 0  2.528409  9.196096    2.563402     8.938459
# 0  2.528680  9.183543    2.563402     8.938459
# 0  2.529213  9.163150    2.563402     8.938459
# 0  2.530895  9.116324    2.563402     8.938459
# ...

# %% [markdown]
# ### LF

# %%
test_perf_path = '/mnt/g/mmsynergy/model/tune/lf/comment/checkpoints/test/'
paths = [test_perf_path+i for i in os.listdir(test_perf_path)]
names = []
all_data = []
for p in paths:
    name = p.split('/')[-1].split('_seq')[0]
    data = torch.load(p)
    data = pd.DataFrame([data])
    data['name'] = name
    all_data.append(data)

all_data = pd.concat(all_data)
all_data = all_data.loc[:, ~all_data.columns.str.contains('random')]
# all_data['improved_mae'] = (all_data['MAE']-all_data['RANDOM MAE'])/all_data['RANDOM MAE']
# all_data['improved_mse'] = (all_data['MSE']-all_data['RANDOM MSE '])/all_data['RANDOM MSE ']
# all_data['RMSE'] = np.sqrt(all_data['MSE'])
# all_data['RANDOM RMSE'] = np.sqrt(all_data['RANDOM MSE '])
# all_data['improved_rmse'] = (all_data['RMSE']-all_data['RANDOM RMSE'])/all_data['RANDOM RMSE']
# all_data.sort_values(by = 'MAE')

# %%
all_data.sort_values(by = 'MAE')
# Out:
#        LOSS       MAE       MSE  RANDOM MAE  RANDOM MSE   \
# 0  1.432947  1.432947  3.544258    1.901197     5.257416
# 0  1.434902  1.434901  3.588744    1.901197     5.257416
# 0  1.435489  1.435489  3.537772    1.901197     5.257416
# 0  1.439218  1.439218  3.552982    1.901197     5.257416
# 0  1.439826  1.439825  3.590352    1.901197     5.257416
# 0  1.448611  1.448611  3.670099    1.901197     5.257416
# 0  1.462593  1.462593  3.693312    1.901197     5.257416
# 0  1.465242  1.465242  3.709000    1.901197     5.257416
# 0  1.468279  1.468279  3.719304    1.901197     5.257416
# 0  1.777748  1.777748  4.973783    1.901197     5.257416
# 0  1.878336  1.878336  5.349271    1.901197     5.257416
# 0  1.879036  1.879037  5.420015    1.901197     5.257416
# 0  1.879047  1.879048  5.389275    1.901197     5.257416
# 0  1.879327  1.879327  5.365195    1.901197     5.257416
# 0  1.879671  1.879671  5.353965    1.901197     5.257416
# ...

# %%
test_perf_path = '/mnt/g/mmsynergy/model/tune/lf/digg/checkpoints/test/'
paths = [test_perf_path+i for i in os.listdir(test_perf_path)]
names = []
all_data = []
for p in paths:
    name = p.split('/')[-1].split('_seq')[0]
    data = torch.load(p)
    data = pd.DataFrame([data])
    data['name'] = name
    all_data.append(data)

all_data = pd.concat(all_data)
all_data = all_data.loc[:, ~all_data.columns.str.contains('random')]
# all_data['improved_mae'] = (all_data['MAE']-all_data['RANDOM MAE'])/all_data['RANDOM MAE']
# all_data['improved_mse'] = (all_data['MSE']-all_data['RANDOM MSE '])/all_data['RANDOM MSE ']
# all_data['RMSE'] = np.sqrt(all_data['MSE'])
# all_data['RANDOM RMSE'] = np.sqrt(all_data['RANDOM MSE '])
# all_data['improved_rmse'] = (all_data['RMSE']-all_data['RANDOM RMSE'])/all_data['RANDOM RMSE']
# all_data.sort_values(by = 'MAE')

# %%
all_data.sort_values(by = 'MAE')
# Out:
#        LOSS       MAE       MSE  RANDOM MAE  RANDOM MSE   \
# 0  1.742082  1.742082  5.885891    2.604568     9.257863
# 0  1.757675  1.757675  5.958031    2.604568     9.257863
# 0  1.759163  1.759163  5.983855    2.604568     9.257863
# 0  1.775711  1.775711  6.110992    2.604568     9.257863
# 0  1.779420  1.779421  5.817352    2.604568     9.257863
# 0  1.795470  1.795470  6.253762    2.604568     9.257863
# 0  1.797402  1.797402  6.028172    2.604568     9.257863
# 0  1.798417  1.798417  6.081231    2.604568     9.257863
# 0  1.810965  1.810965  6.120484    2.604568     9.257863
# 0  2.520680  2.520680  9.344235    2.604568     9.257863
# 0  2.550574  2.550576  9.588201    2.604568     9.257863
# 0  2.550902  2.550903  9.577579    2.604568     9.257863
# 0  2.550958  2.550959  9.575826    2.604568     9.257863
# 0  2.551168  2.551169  9.569296    2.604568     9.257863
# 0  2.552446  2.552446  9.536147    2.604568     9.257863
# ...

# %%
test_perf_path = '/mnt/g/mmsynergy/model/tune/lf/play/checkpoints/test/'
paths = [test_perf_path+i for i in os.listdir(test_perf_path)]
names = []
all_data = []
for p in paths:
    name = p.split('/')[-1].split('_seq')[0]
    data = torch.load(p)
    data = pd.DataFrame([data])
    data['name'] = name
    all_data.append(data)

all_data = pd.concat(all_data)
all_data = all_data.loc[:, ~all_data.columns.str.contains('random')]
# all_data['improved_mae'] = (all_data['MAE']-all_data['RANDOM MAE'])/all_data['RANDOM MAE']
# all_data['improved_mse'] = (all_data['MSE']-all_data['RANDOM MSE '])/all_data['RANDOM MSE ']
# all_data['RMSE'] = np.sqrt(all_data['MSE'])
# all_data['RANDOM RMSE'] = np.sqrt(all_data['RANDOM MSE '])
# all_data['improved_rmse'] = (all_data['RMSE']-all_data['RANDOM RMSE'])/all_data['RANDOM RMSE']
# all_data.sort_values(by = 'MAE')

# %%
all_data.sort_values(by = 'MAE')
# Out:
#        LOSS       MAE       MSE  RANDOM MAE  RANDOM MSE   \
# 0  1.758783  1.758783  5.755101    2.563402     8.938459
# 0  1.761008  1.761009  5.707490    2.563402     8.938459
# 0  1.778372  1.778372  5.637340    2.563402     8.938459
# 0  1.794384  1.794384  5.899131    2.563402     8.938459
# 0  1.796042  1.796042  5.794257    2.563402     8.938459
# 0  1.800145  1.800146  5.957602    2.563402     8.938459
# 0  1.801442  1.801442  6.041842    2.563402     8.938459
# 0  1.825658  1.825658  6.001673    2.563402     8.938459
# 0  1.835209  1.835209  5.932544    2.563402     8.938459
# 0  2.521185  2.521186  9.149040    2.563402     8.938459
# 0  2.530219  2.530217  9.133250    2.563402     8.938459
# 0  2.531176  2.531177  9.109957    2.563402     8.938459
# 0  2.533348  2.533347  9.069976    2.563402     8.938459
# 0  2.533557  2.533556  9.066809    2.563402     8.938459
# 0  2.534881  2.534880  9.048910    2.563402     8.938459
# ...
